# %% [markdown]
# <a href="https://colab.research.google.com/github/pavlovid107b21/lambda/blob/main/dz1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def f(x,y,z):
  return min(x,y,z)

# %%
def f(x,y,z):
  if x == y:
    if x == z:
      return 3
    else:
      return 2
  elif x == z or y == z:
      return 2
  else:
    return 0

# %%
def f(a):
  if len(a) == 10:
      return sum(a)
# Out:
# 45

# %%
def f(a):
  k = 0
  for i in a:
    if i == 0:
      k += 1
  return k
# Out:
# 4
